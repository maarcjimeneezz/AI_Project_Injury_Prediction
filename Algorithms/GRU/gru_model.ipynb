# %% [markdown]
# ## **GRU Model**

# %% [markdown]
# The presented dataset contains longitudinal data which may hide temporal relations with injury incidence. For this reason, we present in this notebook a sequential gated recurrent unit (GRU) model able to capture these temporal dependencies and provide more accurate predictions of injury risk than state-of-the-art models.

# %%
# Dependencies
import copy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import torch
import torch.nn as nn
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader, WeightedRandomSampler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score, roc_auc_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# TO DO: week approach, improve xgboost, plots of performance

# %%
print(device) # Check device
# Out:
# cpu

# %%
# Data loading
day_path = '../Dataset/day_approach_maskedID_timeseries.csv'
week_path = '../Dataset/week_approach_maskedID_timeseries.csv'

# Day and week dataframes
day_df = pd.read_csv(day_path, parse_dates=['Date'])
week_df = pd.read_csv(week_path,  parse_dates=['Date'])
# Out:
# C:\Users\dgaro\AppData\Local\Temp\ipykernel_29276\1165222398.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   day_df = pd.read_csv(day_path, parse_dates=['Date'])
# C:\Users\dgaro\AppData\Local\Temp\ipykernel_29276\1165222398.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   week_df = pd.read_csv(week_path,  parse_dates=['Date'])

# %% [markdown]
# Our model will be trained under specific hyper-parameter combinations:
#
# We performed a hyper-parameter tuning using grid search:
# - **sequence_length**: Length of time points included in a sequence window
# - **hidden_size**: Number of features contained at the hidden state
#
# These other hyper-parameters were fixed during benchmark
# - **epochs**: Number of epochs (Model iterating the whole dataset).
# - **lr**: Learning rate (How fast the model optimizes its parameters).
# - **batch_size**: Number of samples per iteration
# - **patience**: Number of steps to trigger early-stopping during training under a specific condition (in our case that validation loss increses)
#
# For this case, temporal scale is too small to use more complex GRU architectures. Therefore, we build a simple GRU model with a single layer and exclude dropout mechanism as there are not excessive connections.

# %%
# Model hyper-parameter selection
sequence_length = 15
hidden_size = 32

# Fixed hyper-parameter
epochs = 500
lr = 8e-5
batch_size = 512
patience = 20

# %% [markdown]
# ### **Data Preprocessing**

# %% [markdown]
# The model inputs are split into features and labels. The features contain the columns that the model uses to predict the injury risk (matrix of numerical column vectors), while the label tells the actual injury status (binary vector). For the features that we are using to train the model, we exclude the ID of the athlete to avoid bias and date because of temporal gaps. Our model aims to provide general predictions regardless of the athlete.

# %%
# Remove redudant variables
base_features = [
"Athlete ID",
"Date",
"injury",
"nr. sessions",
"total km",
"km Z3-4",
"km Z5-T1-T2",
"km sprinting",
"strength training",
"hours alternative",
"perceived exertion",
"perceived trainingSuccess",
"perceived recovery",
]

# Build our dataset and our feature cols for the inputs, removing unwanted variables
df = day_df[base_features].sort_values(by=['Athlete ID', 'Date'])
df = df.sort_values(["Athlete ID", "Date"]).copy()
feature_cols = [c for c in df.columns if c not in ["injury", "Athlete ID", "Date"]]

# Generate inputs containing the sequences of features and labels
sequence_frames = [] # Feature sequences
sequence_labels = [] # Label sequences

# We generate the sequences by each athlete individually to avoid temporal windows containing data from different athletes
for _, athlete_df in df.groupby("Athlete ID", sort=False):
    athlete_df = athlete_df.sort_values("Date")
    athlete_features = athlete_df[feature_cols].values.astype(np.float32)  
    athlete_labels = athlete_df["injury"].values.astype(np.float32)

    # Temporal points to build the sequences
    for start_idx in range(0, len(athlete_df) - sequence_length + 1, 1): 
        end_idx = start_idx + sequence_length
        sequence_frames.append(athlete_features[start_idx:end_idx]) 
        sequence_labels.append(athlete_labels[end_idx - 1]) # predict the sequence_length day of injury

X_all = np.asarray(sequence_frames, dtype=np.float32)
y_all = np.asarray(sequence_labels, dtype=np.float32)

# Split: 80% train, 10% val, 10% test
X_train_raw, X_valtest_raw, y_train, y_valtest = train_test_split(
    X_all,
    y_all,
    test_size=0.2,
    random_state=42,
    stratify=y_all if len(np.unique(y_all)) > 1 else None,
)

X_val_raw, X_test_raw, y_val, y_test = train_test_split(
    X_valtest_raw,
    y_valtest,
    test_size=0.5,
    random_state=42,
    stratify=y_valtest if len(np.unique(y_valtest)) > 1 else None,
)

# Normalize with train-only statistics
mu = X_train_raw.mean(axis=(0, 1), keepdims=True)
sigma = X_train_raw.std(axis=(0, 1), keepdims=True)
sigma[sigma == 0] = 1.0

X_train = (X_train_raw - mu) / sigma
X_val = (X_val_raw - mu) / sigma
X_test = (X_test_raw - mu) / sigma

# Turn into tensors
X_train_t = torch.tensor(X_train, dtype=torch.float32)
y_train_t = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
X_val_t = torch.tensor(X_val, dtype=torch.float32)
y_val_t = torch.tensor(y_val, dtype=torch.float32).unsqueeze(1)
X_test_t = torch.tensor(X_test, dtype=torch.float32)
y_test_t = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

# %%
X_train_t.shape # (num samples, sequence length, num features)
# Out:
# torch.Size([33384, 15, 10])

# %%
y_train_t.shape # (num samples, injury label)
# Out:
# torch.Size([33384, 1])

# %%
# Class imbalance handling and positive class proportions
num_pos = float((y_train == 1).sum())
num_neg = float((y_train == 0).sum())
pos_weight_value = num_neg / max(num_pos, 1.0)
print(f"Simple workflow - Positive class weight: {pos_weight_value:.4f}")

label_sets = {
    "Train": y_train,
    "Validation": y_val,
    "Test": y_test,
}

for split_name, labels in label_sets.items():
    positive_ratio = (labels == 1).mean()
    print(f"{split_name}: {positive_ratio:.4%} positives ({int((labels == 1).sum())}/{len(labels)})")
# Out:
# Simple workflow - Positive class weight: 74.5294
# Train: 1.3240% positives (442/33384)
# Validation: 1.3180% positives (55/4173)
# Test: 1.3180% positives (55/4173)

# %%
# Injury-label histograms for each split
label_sets = {
    "Train": y_train,
    "Validation": y_val,
    "Test": y_test,
}

fig, axes = plt.subplots(1, 3, figsize=(14, 4), sharey=True)

for ax, (split_name, labels) in zip(axes, label_sets.items()):
    sns.histplot(labels, bins=[-0.5, 0.5, 1.5], discrete=True, ax=ax, color="#4C78A8")
    ax.set_title(f"{split_name} subset")
    ax.set_xlabel("Injury label")
    ax.set_ylabel("Count")
    ax.set_xticks([0, 1])

plt.suptitle("Injury Label Distribution by Data Split", y=1.03)
plt.tight_layout()
plt.show()

# %% [markdown]
# We observed that the proportions of positive samples remains the same in all three subsets, but it is highly unbalanced, which will be considered in further model training and evaluation.

# %% [markdown]
# ### **Model Building and Training**

# %% [markdown]
# In this section we will build and train our GRU model. The training includes a validation subset to regularize the generalization capacity of the model with a early-stopping mechanism to avoid overfitting.

# %%
# DataLoaders (we shuffle to avoid biases)
train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_t, y_val_t), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(TensorDataset(X_test_t, y_test_t), batch_size=batch_size, shuffle=True)

# Build our GRU model (single GRU layer + linear layer): sequence -> binary output
class GRU(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.gru = nn.GRU(input_size=input_size, hidden_size=hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        _, h_n = self.gru(x)
        logits = self.fc(h_n[-1])
        return logits
    
# GRU model
input_size = X_train.shape[2]
model = GRU(input_size=input_size, hidden_size=hidden_size).to(device)

# Loss function: Weighted Binary Cross Entropy (BCE) with the proportion of positives as weight
criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([pos_weight_value], dtype=torch.float32, device=device))

# ADAM optimized
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# Function to evaluate our model (in case of validation subset)
def evaluate(loader, model, criterion, threshold=0.5):
    model.eval() # stop updating parameters, evaluation mode
    total_loss = 0.0
    total_count = 0
    all_probs = []
    all_true = []

    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = criterion(logits, yb)
            probs = torch.sigmoid(logits)

            total_loss += loss.item() * xb.size(0)
            total_count += yb.size(0)
            all_probs.extend(probs.cpu().numpy().flatten().tolist())
            all_true.extend(yb.cpu().numpy().astype(int).flatten().tolist())

    avg_loss = total_loss / max(total_count, 1)
    preds = (np.array(all_probs) >= threshold).astype(int) # positives will be considered those ones above the threshold
    true = np.array(all_true).astype(int)
    return avg_loss, true, np.array(all_probs), preds

# %% [markdown]
# Training loops stores the update in both training and validation losses to plot their evolution over epochs. In a suitable case, both loss curves should have the same decreasing shape. However, in many cases the validation loss curve achieves a plateau while training loss curve continues to diminish. If the validation loss curve start increases, the model is overfitting and we have to trigger an early-stopping mechanism.

# %%
# Training with early stopping on validation loss. Set initial values
best_val_loss = float("inf") # start at maximum
best_state_dict = copy.deepcopy(model.state_dict()) 
patience_counter = 0

# Recorded values
train_loss_history = []
val_loss_history = []

print("\n========== Training Simple Workflow ==========%s" % "")

# Training loop
for epoch in range(epochs):
    model.train() # update parameters
    train_loss, train_total = 0.0, 0

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)

        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * xb.size(0)
        train_total += yb.size(0)

    train_loss /= max(train_total, 1)

    val_loss, _, _, _ = evaluate(val_loader, model, criterion, threshold=0.5)

    train_loss_history.append(train_loss)
    val_loss_history.append(val_loss)

    # Patience counter increase condition (validation loss increases)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = copy.deepcopy(model.state_dict())
        patience_counter = 0
    else:
        patience_counter += 1

    print(
        f"Epoch [{epoch+1}/{epochs}] ",
        f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Patience: {patience_counter}/{patience}"
    )

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch+1}.")
        break

model.load_state_dict(best_state_dict)
torch.save(model.state_dict(), "trained_model.pt")
print("Best model saved as trained_model.pt")

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, marker='o', linewidth=2, label='Train Loss')
plt.plot(range(1, len(val_loss_history) + 1), val_loss_history, marker='s', linewidth=2, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss Across Epochs')
plt.grid(alpha=0.25)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ========== Training Simple Workflow ==========
# Epoch [1/500]  Train Loss: 1.3632 | Val Loss: 1.3697 | Patience: 0/20
# Epoch [2/500]  Train Loss: 1.3614 | Val Loss: 1.3675 | Patience: 0/20
# Epoch [3/500]  Train Loss: 1.3596 | Val Loss: 1.3655 | Patience: 0/20
# Epoch [4/500]  Train Loss: 1.3580 | Val Loss: 1.3633 | Patience: 0/20
# Epoch [5/500]  Train Loss: 1.3563 | Val Loss: 1.3613 | Patience: 0/20
# Epoch [6/500]  Train Loss: 1.3547 | Val Loss: 1.3595 | Patience: 0/20
# Epoch [7/500]  Train Loss: 1.3533 | Val Loss: 1.3570 | Patience: 0/20
# Epoch [8/500]  Train Loss: 1.3516 | Val Loss: 1.3554 | Patience: 0/20
# Epoch [9/500]  Train Loss: 1.3500 | Val Loss: 1.3534 | Patience: 0/20
# Epoch [10/500]  Train Loss: 1.3483 | Val Loss: 1.3513 | Patience: 0/20
# Epoch [11/500]  Train Loss: 1.3466 | Val Loss: 1.3493 | Patience: 0/20
# Epoch [12/500]  Train Loss: 1.3449 | Val Loss: 1.3474 | Patience: 0/20
# Epoch [13/500]  Train Loss: 1.3432 | Val Loss: 1.3454 | Patience: 0/20
# Epoch [14/500]  Train Loss: 1.3415 | Val Loss: 1.3430 | Patience: 0/20
# Epoch [15/500]  Train Loss: 1.3397 | Val Loss: 1.3409 | Patience: 0/20
# Epoch [16/500]  Train Loss: 1.3376 | Val Loss: 1.3391 | Patience: 0/20
# Epoch [17/500]  Train Loss: 1.3358 | Val Loss: 1.3371 | Patience: 0/20
# Epoch [18/500]  Train Loss: 1.3338 | Val Loss: 1.3349 | Patience: 0/20
# Epoch [19/500]  Train Loss: 1.3318 | Val Loss: 1.3326 | Patience: 0/20
# Epoch [20/500]  Train Loss: 1.3296 | Val Loss: 1.3303 | Patience: 0/20
# Epoch [21/500]  Train Loss: 1.3273 | Val Loss: 1.3279 | Patience: 0/20
# Epoch [22/500]  Train Loss: 1.3252 | Val Loss: 1.3258 | Patience: 0/20
# Epoch [23/500]  Train Loss: 1.3229 | Val Loss: 1.3232 | Patience: 0/20
# Epoch [24/500]  Train Loss: 1.3204 | Val Loss: 1.3208 | Patience: 0/20
# Epoch [25/500]  Train Loss: 1.3181 | Val Loss: 1.3183 | Patience: 0/20
# Epoch [26/500]  Train Loss: 1.3156 | Val Loss: 1.3158 | Patience: 0/20
# Epoch [27/500]  Train Loss: 1.3129 | Val Loss: 1.3137 | Patience: 0/20
# Epoch [28/500]  Train Loss: 1.3102 | Val Loss: 1.3109 | Patience: 0/20
# Epoch [29/500]  Train Loss: 1.3075 | Val Loss: 1.3082 | Patience: 0/20
# Epoch [30/500]  Train Loss: 1.3048 | Val Loss: 1.3060 | Patience: 0/20
# Epoch [31/500]  Train Loss: 1.3022 | Val Loss: 1.3035 | Patience: 0/20
# Epoch [32/500]  Train Loss: 1.2995 | Val Loss: 1.3015 | Patience: 0/20
# Epoch [33/500]  Train Loss: 1.2968 | Val Loss: 1.2991 | Patience: 0/20
# Epoch [34/500]  Train Loss: 1.2939 | Val Loss: 1.2972 | Patience: 0/20
# Epoch [35/500]  Train Loss: 1.2910 | Val Loss: 1.2956 | Patience: 0/20
# Epoch [36/500]  Train Loss: 1.2881 | Val Loss: 1.2935 | Patience: 0/20
# Epoch [37/500]  Train Loss: 1.2851 | Val Loss: 1.2912 | Patience: 0/20
# Epoch [38/500]  Train Loss: 1.2823 | Val Loss: 1.2895 | Patience: 0/20
# Epoch [39/500]  Train Loss: 1.2793 | Val Loss: 1.2868 | Patience: 0/20
# Epoch [40/500]  Train Loss: 1.2763 | Val Loss: 1.2852 | Patience: 0/20
# Epoch [41/500]  Train Loss: 1.2733 | Val Loss: 1.2825 | Patience: 0/20
# Epoch [42/500]  Train Loss: 1.2702 | Val Loss: 1.2806 | Patience: 0/20
# Epoch [43/500]  Train Loss: 1.2673 | Val Loss: 1.2783 | Patience: 0/20
# Epoch [44/500]  Train Loss: 1.2644 | Val Loss: 1.2768 | Patience: 0/20
# Epoch [45/500]  Train Loss: 1.2610 | Val Loss: 1.2746 | Patience: 0/20
# Epoch [46/500]  Train Loss: 1.2581 | Val Loss: 1.2724 | Patience: 0/20
# Epoch [47/500]  Train Loss: 1.2550 | Val Loss: 1.2699 | Patience: 0/20
# Epoch [48/500]  Train Loss: 1.2520 | Val Loss: 1.2678 | Patience: 0/20
# Epoch [49/500]  Train Loss: 1.2490 | Val Loss: 1.2656 | Patience: 0/20
# Epoch [50/500]  Train Loss: 1.2463 | Val Loss: 1.2632 | Patience: 0/20
# Epoch [51/500]  Train Loss: 1.2431 | Val Loss: 1.2607 | Patience: 0/20
# Epoch [52/500]  Train Loss: 1.2403 | Val Loss: 1.2588 | Patience: 0/20
# Epoch [53/500]  Train Loss: 1.2371 | Val Loss: 1.2563 | Patience: 0/20
# Epoch [54/500]  Train Loss: 1.2343 | Val Loss: 1.2540 | Patience: 0/20
# Epoch [55/500]  Train Loss: 1.2317 | Val Loss: 1.2513 | Patience: 0/20
# Epoch [56/500]  Train Loss: 1.2292 | Val Loss: 1.2494 | Patience: 0/20
# Epoch [57/500]  Train Loss: 1.2263 | Val Loss: 1.2471 | Patience: 0/20
# Epoch [58/500]  Train Loss: 1.2237 | Val Loss: 1.2448 | Patience: 0/20
# Epoch [59/500]  Train Loss: 1.2209 | Val Loss: 1.2435 | Patience: 0/20
# Epoch [60/500]  Train Loss: 1.2184 | Val Loss: 1.2413 | Patience: 0/20
# Epoch [61/500]  Train Loss: 1.2161 | Val Loss: 1.2389 | Patience: 0/20
# Epoch [62/500]  Train Loss: 1.2136 | Val Loss: 1.2371 | Patience: 0/20
# Epoch [63/500]  Train Loss: 1.2110 | Val Loss: 1.2355 | Patience: 0/20
# Epoch [64/500]  Train Loss: 1.2092 | Val Loss: 1.2335 | Patience: 0/20
# Epoch [65/500]  Train Loss: 1.2062 | Val Loss: 1.2318 | Patience: 0/20
# Epoch [66/500]  Train Loss: 1.2041 | Val Loss: 1.2299 | Patience: 0/20
# Epoch [67/500]  Train Loss: 1.2018 | Val Loss: 1.2275 | Patience: 0/20
# Epoch [68/500]  Train Loss: 1.1999 | Val Loss: 1.2256 | Patience: 0/20
# Epoch [69/500]  Train Loss: 1.1972 | Val Loss: 1.2242 | Patience: 0/20
# Epoch [70/500]  Train Loss: 1.1952 | Val Loss: 1.2221 | Patience: 0/20
# Epoch [71/500]  Train Loss: 1.1932 | Val Loss: 1.2206 | Patience: 0/20
# Epoch [72/500]  Train Loss: 1.1908 | Val Loss: 1.2196 | Patience: 0/20
# Epoch [73/500]  Train Loss: 1.1887 | Val Loss: 1.2181 | Patience: 0/20
# Epoch [74/500]  Train Loss: 1.1867 | Val Loss: 1.2162 | Patience: 0/20
# Epoch [75/500]  Train Loss: 1.1844 | Val Loss: 1.2146 | Patience: 0/20
# Epoch [76/500]  Train Loss: 1.1828 | Val Loss: 1.2132 | Patience: 0/20
# Epoch [77/500]  Train Loss: 1.1807 | Val Loss: 1.2123 | Patience: 0/20
# Epoch [78/500]  Train Loss: 1.1786 | Val Loss: 1.2101 | Patience: 0/20
# Epoch [79/500]  Train Loss: 1.1768 | Val Loss: 1.2086 | Patience: 0/20
# Epoch [80/500]  Train Loss: 1.1747 | Val Loss: 1.2075 | Patience: 0/20
# Epoch [81/500]  Train Loss: 1.1733 | Val Loss: 1.2064 | Patience: 0/20
# Epoch [82/500]  Train Loss: 1.1711 | Val Loss: 1.2050 | Patience: 0/20
# Epoch [83/500]  Train Loss: 1.1693 | Val Loss: 1.2036 | Patience: 0/20
# Epoch [84/500]  Train Loss: 1.1674 | Val Loss: 1.2025 | Patience: 0/20
# Epoch [85/500]  Train Loss: 1.1656 | Val Loss: 1.2011 | Patience: 0/20
# Epoch [86/500]  Train Loss: 1.1640 | Val Loss: 1.2000 | Patience: 0/20
# Epoch [87/500]  Train Loss: 1.1627 | Val Loss: 1.1985 | Patience: 0/20
# Epoch [88/500]  Train Loss: 1.1608 | Val Loss: 1.1971 | Patience: 0/20
# Epoch [89/500]  Train Loss: 1.1593 | Val Loss: 1.1956 | Patience: 0/20
# Epoch [90/500]  Train Loss: 1.1572 | Val Loss: 1.1953 | Patience: 0/20
# Epoch [91/500]  Train Loss: 1.1561 | Val Loss: 1.1931 | Patience: 0/20
# Epoch [92/500]  Train Loss: 1.1544 | Val Loss: 1.1932 | Patience: 1/20
# Epoch [93/500]  Train Loss: 1.1527 | Val Loss: 1.1924 | Patience: 0/20
# Epoch [94/500]  Train Loss: 1.1516 | Val Loss: 1.1911 | Patience: 0/20
# Epoch [95/500]  Train Loss: 1.1499 | Val Loss: 1.1898 | Patience: 0/20
# Epoch [96/500]  Train Loss: 1.1484 | Val Loss: 1.1888 | Patience: 0/20
# Epoch [97/500]  Train Loss: 1.1470 | Val Loss: 1.1881 | Patience: 0/20
# Epoch [98/500]  Train Loss: 1.1456 | Val Loss: 1.1865 | Patience: 0/20
# Epoch [99/500]  Train Loss: 1.1439 | Val Loss: 1.1863 | Patience: 0/20
# Epoch [100/500]  Train Loss: 1.1428 | Val Loss: 1.1836 | Patience: 0/20
# Epoch [101/500]  Train Loss: 1.1414 | Val Loss: 1.1831 | Patience: 0/20
# Epoch [102/500]  Train Loss: 1.1402 | Val Loss: 1.1817 | Patience: 0/20
# Epoch [103/500]  Train Loss: 1.1390 | Val Loss: 1.1805 | Patience: 0/20
# Epoch [104/500]  Train Loss: 1.1368 | Val Loss: 1.1799 | Patience: 0/20
# Epoch [105/500]  Train Loss: 1.1359 | Val Loss: 1.1785 | Patience: 0/20
# Epoch [106/500]  Train Loss: 1.1347 | Val Loss: 1.1788 | Patience: 1/20
# Epoch [107/500]  Train Loss: 1.1334 | Val Loss: 1.1779 | Patience: 0/20
# Epoch [108/500]  Train Loss: 1.1315 | Val Loss: 1.1763 | Patience: 0/20
# Epoch [109/500]  Train Loss: 1.1306 | Val Loss: 1.1743 | Patience: 0/20
# Epoch [110/500]  Train Loss: 1.1291 | Val Loss: 1.1737 | Patience: 0/20
# Epoch [111/500]  Train Loss: 1.1278 | Val Loss: 1.1728 | Patience: 0/20
# Epoch [112/500]  Train Loss: 1.1272 | Val Loss: 1.1722 | Patience: 0/20
# Epoch [113/500]  Train Loss: 1.1256 | Val Loss: 1.1710 | Patience: 0/20
# Epoch [114/500]  Train Loss: 1.1248 | Val Loss: 1.1712 | Patience: 1/20
# Epoch [115/500]  Train Loss: 1.1232 | Val Loss: 1.1695 | Patience: 0/20
# Epoch [116/500]  Train Loss: 1.1216 | Val Loss: 1.1679 | Patience: 0/20
# Epoch [117/500]  Train Loss: 1.1206 | Val Loss: 1.1673 | Patience: 0/20
# Epoch [118/500]  Train Loss: 1.1193 | Val Loss: 1.1659 | Patience: 0/20
# Epoch [119/500]  Train Loss: 1.1178 | Val Loss: 1.1662 | Patience: 1/20
# Epoch [120/500]  Train Loss: 1.1172 | Val Loss: 1.1644 | Patience: 0/20
# Epoch [121/500]  Train Loss: 1.1160 | Val Loss: 1.1640 | Patience: 0/20
# Epoch [122/500]  Train Loss: 1.1152 | Val Loss: 1.1640 | Patience: 1/20
# Epoch [123/500]  Train Loss: 1.1132 | Val Loss: 1.1631 | Patience: 0/20
# Epoch [124/500]  Train Loss: 1.1125 | Val Loss: 1.1618 | Patience: 0/20
# Epoch [125/500]  Train Loss: 1.1113 | Val Loss: 1.1616 | Patience: 0/20
# Epoch [126/500]  Train Loss: 1.1101 | Val Loss: 1.1606 | Patience: 0/20
# Epoch [127/500]  Train Loss: 1.1093 | Val Loss: 1.1596 | Patience: 0/20
# Epoch [128/500]  Train Loss: 1.1078 | Val Loss: 1.1584 | Patience: 0/20
# Epoch [129/500]  Train Loss: 1.1067 | Val Loss: 1.1577 | Patience: 0/20
# Epoch [130/500]  Train Loss: 1.1055 | Val Loss: 1.1572 | Patience: 0/20
# Epoch [131/500]  Train Loss: 1.1052 | Val Loss: 1.1567 | Patience: 0/20
# Epoch [132/500]  Train Loss: 1.1030 | Val Loss: 1.1549 | Patience: 0/20
# Epoch [133/500]  Train Loss: 1.1022 | Val Loss: 1.1541 | Patience: 0/20
# Epoch [134/500]  Train Loss: 1.1010 | Val Loss: 1.1527 | Patience: 0/20
# Epoch [135/500]  Train Loss: 1.1000 | Val Loss: 1.1520 | Patience: 0/20
# Epoch [136/500]  Train Loss: 1.0989 | Val Loss: 1.1522 | Patience: 1/20
# Epoch [137/500]  Train Loss: 1.0973 | Val Loss: 1.1505 | Patience: 0/20
# Epoch [138/500]  Train Loss: 1.0967 | Val Loss: 1.1497 | Patience: 0/20
# Epoch [139/500]  Train Loss: 1.0950 | Val Loss: 1.1495 | Patience: 0/20
# Epoch [140/500]  Train Loss: 1.0942 | Val Loss: 1.1476 | Patience: 0/20
# Epoch [141/500]  Train Loss: 1.0937 | Val Loss: 1.1480 | Patience: 1/20
# Epoch [142/500]  Train Loss: 1.0922 | Val Loss: 1.1468 | Patience: 0/20
# Epoch [143/500]  Train Loss: 1.0914 | Val Loss: 1.1457 | Patience: 0/20
# Epoch [144/500]  Train Loss: 1.0906 | Val Loss: 1.1450 | Patience: 0/20
# Epoch [145/500]  Train Loss: 1.0888 | Val Loss: 1.1447 | Patience: 0/20
# Epoch [146/500]  Train Loss: 1.0879 | Val Loss: 1.1430 | Patience: 0/20
# Epoch [147/500]  Train Loss: 1.0866 | Val Loss: 1.1423 | Patience: 0/20
# Epoch [148/500]  Train Loss: 1.0857 | Val Loss: 1.1408 | Patience: 0/20
# Epoch [149/500]  Train Loss: 1.0851 | Val Loss: 1.1398 | Patience: 0/20
# Epoch [150/500]  Train Loss: 1.0837 | Val Loss: 1.1402 | Patience: 1/20
# Epoch [151/500]  Train Loss: 1.0828 | Val Loss: 1.1389 | Patience: 0/20
# Epoch [152/500]  Train Loss: 1.0814 | Val Loss: 1.1378 | Patience: 0/20
# Epoch [153/500]  Train Loss: 1.0805 | Val Loss: 1.1366 | Patience: 0/20
# Epoch [154/500]  Train Loss: 1.0792 | Val Loss: 1.1365 | Patience: 0/20
# Epoch [155/500]  Train Loss: 1.0789 | Val Loss: 1.1355 | Patience: 0/20
# Epoch [156/500]  Train Loss: 1.0774 | Val Loss: 1.1337 | Patience: 0/20
# Epoch [157/500]  Train Loss: 1.0770 | Val Loss: 1.1339 | Patience: 1/20
# Epoch [158/500]  Train Loss: 1.0752 | Val Loss: 1.1322 | Patience: 0/20
# Epoch [159/500]  Train Loss: 1.0748 | Val Loss: 1.1320 | Patience: 0/20
# Epoch [160/500]  Train Loss: 1.0731 | Val Loss: 1.1312 | Patience: 0/20
# Epoch [161/500]  Train Loss: 1.0720 | Val Loss: 1.1315 | Patience: 1/20
# Epoch [162/500]  Train Loss: 1.0714 | Val Loss: 1.1292 | Patience: 0/20
# Epoch [163/500]  Train Loss: 1.0699 | Val Loss: 1.1293 | Patience: 1/20
# Epoch [164/500]  Train Loss: 1.0687 | Val Loss: 1.1287 | Patience: 0/20
# Epoch [165/500]  Train Loss: 1.0682 | Val Loss: 1.1280 | Patience: 0/20
# Epoch [166/500]  Train Loss: 1.0667 | Val Loss: 1.1272 | Patience: 0/20
# Epoch [167/500]  Train Loss: 1.0656 | Val Loss: 1.1261 | Patience: 0/20
# Epoch [168/500]  Train Loss: 1.0654 | Val Loss: 1.1246 | Patience: 0/20
# Epoch [169/500]  Train Loss: 1.0639 | Val Loss: 1.1246 | Patience: 0/20
# Epoch [170/500]  Train Loss: 1.0630 | Val Loss: 1.1240 | Patience: 0/20
# Epoch [171/500]  Train Loss: 1.0617 | Val Loss: 1.1225 | Patience: 0/20
# Epoch [172/500]  Train Loss: 1.0609 | Val Loss: 1.1217 | Patience: 0/20
# Epoch [173/500]  Train Loss: 1.0593 | Val Loss: 1.1206 | Patience: 0/20
# Epoch [174/500]  Train Loss: 1.0590 | Val Loss: 1.1198 | Patience: 0/20
# Epoch [175/500]  Train Loss: 1.0580 | Val Loss: 1.1194 | Patience: 0/20
# Epoch [176/500]  Train Loss: 1.0570 | Val Loss: 1.1189 | Patience: 0/20
# Epoch [177/500]  Train Loss: 1.0559 | Val Loss: 1.1168 | Patience: 0/20
# Epoch [178/500]  Train Loss: 1.0559 | Val Loss: 1.1169 | Patience: 1/20
# Epoch [179/500]  Train Loss: 1.0538 | Val Loss: 1.1164 | Patience: 0/20
# Epoch [180/500]  Train Loss: 1.0527 | Val Loss: 1.1153 | Patience: 0/20
# Epoch [181/500]  Train Loss: 1.0518 | Val Loss: 1.1141 | Patience: 0/20
# Epoch [182/500]  Train Loss: 1.0505 | Val Loss: 1.1162 | Patience: 1/20
# Epoch [183/500]  Train Loss: 1.0493 | Val Loss: 1.1139 | Patience: 0/20
# Epoch [184/500]  Train Loss: 1.0491 | Val Loss: 1.1133 | Patience: 0/20
# Epoch [185/500]  Train Loss: 1.0477 | Val Loss: 1.1135 | Patience: 1/20
# Epoch [186/500]  Train Loss: 1.0468 | Val Loss: 1.1119 | Patience: 0/20
# Epoch [187/500]  Train Loss: 1.0465 | Val Loss: 1.1112 | Patience: 0/20
# Epoch [188/500]  Train Loss: 1.0446 | Val Loss: 1.1091 | Patience: 0/20
# Epoch [189/500]  Train Loss: 1.0433 | Val Loss: 1.1077 | Patience: 0/20
# Epoch [190/500]  Train Loss: 1.0434 | Val Loss: 1.1079 | Patience: 1/20
# Epoch [191/500]  Train Loss: 1.0428 | Val Loss: 1.1077 | Patience: 0/20
# Epoch [192/500]  Train Loss: 1.0411 | Val Loss: 1.1060 | Patience: 0/20
# Epoch [193/500]  Train Loss: 1.0401 | Val Loss: 1.1072 | Patience: 1/20
# Epoch [194/500]  Train Loss: 1.0388 | Val Loss: 1.1057 | Patience: 0/20
# Epoch [195/500]  Train Loss: 1.0385 | Val Loss: 1.1051 | Patience: 0/20
# Epoch [196/500]  Train Loss: 1.0365 | Val Loss: 1.1040 | Patience: 0/20
# Epoch [197/500]  Train Loss: 1.0356 | Val Loss: 1.1015 | Patience: 0/20
# Epoch [198/500]  Train Loss: 1.0343 | Val Loss: 1.1019 | Patience: 1/20
# Epoch [199/500]  Train Loss: 1.0339 | Val Loss: 1.1008 | Patience: 0/20
# Epoch [200/500]  Train Loss: 1.0339 | Val Loss: 1.1009 | Patience: 1/20
# Epoch [201/500]  Train Loss: 1.0316 | Val Loss: 1.0994 | Patience: 0/20
# Epoch [202/500]  Train Loss: 1.0307 | Val Loss: 1.0991 | Patience: 0/20
# Epoch [203/500]  Train Loss: 1.0292 | Val Loss: 1.0973 | Patience: 0/20
# Epoch [204/500]  Train Loss: 1.0287 | Val Loss: 1.0958 | Patience: 0/20
# Epoch [205/500]  Train Loss: 1.0275 | Val Loss: 1.0966 | Patience: 1/20
# Epoch [206/500]  Train Loss: 1.0266 | Val Loss: 1.0951 | Patience: 0/20
# Epoch [207/500]  Train Loss: 1.0255 | Val Loss: 1.0946 | Patience: 0/20
# Epoch [208/500]  Train Loss: 1.0257 | Val Loss: 1.0955 | Patience: 1/20
# Epoch [209/500]  Train Loss: 1.0238 | Val Loss: 1.0929 | Patience: 0/20
# Epoch [210/500]  Train Loss: 1.0224 | Val Loss: 1.0923 | Patience: 0/20
# Epoch [211/500]  Train Loss: 1.0221 | Val Loss: 1.0911 | Patience: 0/20
# Epoch [212/500]  Train Loss: 1.0213 | Val Loss: 1.0899 | Patience: 0/20
# Epoch [213/500]  Train Loss: 1.0202 | Val Loss: 1.0893 | Patience: 0/20
# Epoch [214/500]  Train Loss: 1.0191 | Val Loss: 1.0882 | Patience: 0/20
# Epoch [215/500]  Train Loss: 1.0177 | Val Loss: 1.0883 | Patience: 1/20
# Epoch [216/500]  Train Loss: 1.0174 | Val Loss: 1.0887 | Patience: 2/20
# Epoch [217/500]  Train Loss: 1.0164 | Val Loss: 1.0867 | Patience: 0/20
# Epoch [218/500]  Train Loss: 1.0150 | Val Loss: 1.0867 | Patience: 1/20
# Epoch [219/500]  Train Loss: 1.0142 | Val Loss: 1.0853 | Patience: 0/20
# Epoch [220/500]  Train Loss: 1.0127 | Val Loss: 1.0846 | Patience: 0/20
# Epoch [221/500]  Train Loss: 1.0114 | Val Loss: 1.0839 | Patience: 0/20
# Epoch [222/500]  Train Loss: 1.0101 | Val Loss: 1.0822 | Patience: 0/20
# Epoch [223/500]  Train Loss: 1.0097 | Val Loss: 1.0827 | Patience: 1/20
# Epoch [224/500]  Train Loss: 1.0086 | Val Loss: 1.0823 | Patience: 2/20
# Epoch [225/500]  Train Loss: 1.0078 | Val Loss: 1.0789 | Patience: 0/20
# Epoch [226/500]  Train Loss: 1.0059 | Val Loss: 1.0777 | Patience: 0/20
# Epoch [227/500]  Train Loss: 1.0058 | Val Loss: 1.0804 | Patience: 1/20
# Epoch [228/500]  Train Loss: 1.0048 | Val Loss: 1.0782 | Patience: 2/20
# Epoch [229/500]  Train Loss: 1.0030 | Val Loss: 1.0768 | Patience: 0/20
# Epoch [230/500]  Train Loss: 1.0029 | Val Loss: 1.0768 | Patience: 1/20
# Epoch [231/500]  Train Loss: 1.0015 | Val Loss: 1.0758 | Patience: 0/20
# Epoch [232/500]  Train Loss: 1.0001 | Val Loss: 1.0752 | Patience: 0/20
# Epoch [233/500]  Train Loss: 0.9995 | Val Loss: 1.0739 | Patience: 0/20
# Epoch [234/500]  Train Loss: 0.9981 | Val Loss: 1.0729 | Patience: 0/20
# Epoch [235/500]  Train Loss: 0.9974 | Val Loss: 1.0727 | Patience: 0/20
# Epoch [236/500]  Train Loss: 0.9961 | Val Loss: 1.0712 | Patience: 0/20
# Epoch [237/500]  Train Loss: 0.9952 | Val Loss: 1.0720 | Patience: 1/20
# Epoch [238/500]  Train Loss: 0.9938 | Val Loss: 1.0702 | Patience: 0/20
# Epoch [239/500]  Train Loss: 0.9928 | Val Loss: 1.0703 | Patience: 1/20
# Epoch [240/500]  Train Loss: 0.9924 | Val Loss: 1.0684 | Patience: 0/20
# Epoch [241/500]  Train Loss: 0.9914 | Val Loss: 1.0683 | Patience: 0/20
# Epoch [242/500]  Train Loss: 0.9909 | Val Loss: 1.0699 | Patience: 1/20
# Epoch [243/500]  Train Loss: 0.9899 | Val Loss: 1.0672 | Patience: 0/20
# Epoch [244/500]  Train Loss: 0.9882 | Val Loss: 1.0670 | Patience: 0/20
# Epoch [245/500]  Train Loss: 0.9869 | Val Loss: 1.0659 | Patience: 0/20
# Epoch [246/500]  Train Loss: 0.9861 | Val Loss: 1.0646 | Patience: 0/20
# Epoch [247/500]  Train Loss: 0.9860 | Val Loss: 1.0640 | Patience: 0/20
# Epoch [248/500]  Train Loss: 0.9836 | Val Loss: 1.0631 | Patience: 0/20
# Epoch [249/500]  Train Loss: 0.9833 | Val Loss: 1.0615 | Patience: 0/20
# Epoch [250/500]  Train Loss: 0.9826 | Val Loss: 1.0601 | Patience: 0/20
# Epoch [251/500]  Train Loss: 0.9808 | Val Loss: 1.0618 | Patience: 1/20
# Epoch [252/500]  Train Loss: 0.9809 | Val Loss: 1.0614 | Patience: 2/20
# Epoch [253/500]  Train Loss: 0.9801 | Val Loss: 1.0588 | Patience: 0/20
# Epoch [254/500]  Train Loss: 0.9784 | Val Loss: 1.0585 | Patience: 0/20
# Epoch [255/500]  Train Loss: 0.9782 | Val Loss: 1.0588 | Patience: 1/20
# Epoch [256/500]  Train Loss: 0.9764 | Val Loss: 1.0577 | Patience: 0/20
# Epoch [257/500]  Train Loss: 0.9758 | Val Loss: 1.0568 | Patience: 0/20
# Epoch [258/500]  Train Loss: 0.9745 | Val Loss: 1.0564 | Patience: 0/20
# Epoch [259/500]  Train Loss: 0.9756 | Val Loss: 1.0558 | Patience: 0/20
# Epoch [260/500]  Train Loss: 0.9727 | Val Loss: 1.0547 | Patience: 0/20
# Epoch [261/500]  Train Loss: 0.9722 | Val Loss: 1.0539 | Patience: 0/20
# Epoch [262/500]  Train Loss: 0.9710 | Val Loss: 1.0521 | Patience: 0/20
# Epoch [263/500]  Train Loss: 0.9705 | Val Loss: 1.0521 | Patience: 1/20
# Epoch [264/500]  Train Loss: 0.9681 | Val Loss: 1.0510 | Patience: 0/20
# Epoch [265/500]  Train Loss: 0.9671 | Val Loss: 1.0512 | Patience: 1/20
# Epoch [266/500]  Train Loss: 0.9660 | Val Loss: 1.0502 | Patience: 0/20
# Epoch [267/500]  Train Loss: 0.9661 | Val Loss: 1.0498 | Patience: 0/20
# Epoch [268/500]  Train Loss: 0.9651 | Val Loss: 1.0496 | Patience: 0/20
# Epoch [269/500]  Train Loss: 0.9642 | Val Loss: 1.0486 | Patience: 0/20
# Epoch [270/500]  Train Loss: 0.9654 | Val Loss: 1.0515 | Patience: 1/20
# Epoch [271/500]  Train Loss: 0.9622 | Val Loss: 1.0483 | Patience: 0/20
# Epoch [272/500]  Train Loss: 0.9601 | Val Loss: 1.0494 | Patience: 1/20
# Epoch [273/500]  Train Loss: 0.9601 | Val Loss: 1.0486 | Patience: 2/20
# Epoch [274/500]  Train Loss: 0.9593 | Val Loss: 1.0473 | Patience: 0/20
# Epoch [275/500]  Train Loss: 0.9581 | Val Loss: 1.0453 | Patience: 0/20
# Epoch [276/500]  Train Loss: 0.9582 | Val Loss: 1.0462 | Patience: 1/20
# Epoch [277/500]  Train Loss: 0.9553 | Val Loss: 1.0434 | Patience: 0/20
# Epoch [278/500]  Train Loss: 0.9546 | Val Loss: 1.0423 | Patience: 0/20
# Epoch [279/500]  Train Loss: 0.9540 | Val Loss: 1.0407 | Patience: 0/20
# Epoch [280/500]  Train Loss: 0.9532 | Val Loss: 1.0414 | Patience: 1/20
# Epoch [281/500]  Train Loss: 0.9526 | Val Loss: 1.0384 | Patience: 0/20
# Epoch [282/500]  Train Loss: 0.9531 | Val Loss: 1.0382 | Patience: 0/20
# Epoch [283/500]  Train Loss: 0.9504 | Val Loss: 1.0381 | Patience: 0/20
# Epoch [284/500]  Train Loss: 0.9492 | Val Loss: 1.0381 | Patience: 0/20
# Epoch [285/500]  Train Loss: 0.9488 | Val Loss: 1.0379 | Patience: 0/20
# Epoch [286/500]  Train Loss: 0.9492 | Val Loss: 1.0376 | Patience: 0/20
# Epoch [287/500]  Train Loss: 0.9473 | Val Loss: 1.0373 | Patience: 0/20
# Epoch [288/500]  Train Loss: 0.9464 | Val Loss: 1.0378 | Patience: 1/20
# Epoch [289/500]  Train Loss: 0.9456 | Val Loss: 1.0362 | Patience: 0/20
# Epoch [290/500]  Train Loss: 0.9443 | Val Loss: 1.0359 | Patience: 0/20
# Epoch [291/500]  Train Loss: 0.9433 | Val Loss: 1.0342 | Patience: 0/20
# Epoch [292/500]  Train Loss: 0.9426 | Val Loss: 1.0341 | Patience: 0/20
# Epoch [293/500]  Train Loss: 0.9416 | Val Loss: 1.0337 | Patience: 0/20
# Epoch [294/500]  Train Loss: 0.9431 | Val Loss: 1.0317 | Patience: 0/20
# Epoch [295/500]  Train Loss: 0.9397 | Val Loss: 1.0332 | Patience: 1/20
# Epoch [296/500]  Train Loss: 0.9389 | Val Loss: 1.0328 | Patience: 2/20
# Epoch [297/500]  Train Loss: 0.9369 | Val Loss: 1.0315 | Patience: 0/20
# Epoch [298/500]  Train Loss: 0.9369 | Val Loss: 1.0323 | Patience: 1/20
# Epoch [299/500]  Train Loss: 0.9347 | Val Loss: 1.0294 | Patience: 0/20
# Epoch [300/500]  Train Loss: 0.9345 | Val Loss: 1.0293 | Patience: 0/20
# Epoch [301/500]  Train Loss: 0.9332 | Val Loss: 1.0262 | Patience: 0/20
# Epoch [302/500]  Train Loss: 0.9337 | Val Loss: 1.0273 | Patience: 1/20
# Epoch [303/500]  Train Loss: 0.9334 | Val Loss: 1.0264 | Patience: 2/20
# Epoch [304/500]  Train Loss: 0.9313 | Val Loss: 1.0261 | Patience: 0/20
# Epoch [305/500]  Train Loss: 0.9294 | Val Loss: 1.0251 | Patience: 0/20
# Epoch [306/500]  Train Loss: 0.9282 | Val Loss: 1.0243 | Patience: 0/20
# Epoch [307/500]  Train Loss: 0.9280 | Val Loss: 1.0249 | Patience: 1/20
# Epoch [308/500]  Train Loss: 0.9285 | Val Loss: 1.0240 | Patience: 0/20
# Epoch [309/500]  Train Loss: 0.9259 | Val Loss: 1.0226 | Patience: 0/20
# Epoch [310/500]  Train Loss: 0.9258 | Val Loss: 1.0233 | Patience: 1/20
# Epoch [311/500]  Train Loss: 0.9243 | Val Loss: 1.0227 | Patience: 2/20
# Epoch [312/500]  Train Loss: 0.9237 | Val Loss: 1.0230 | Patience: 3/20
# Epoch [313/500]  Train Loss: 0.9220 | Val Loss: 1.0209 | Patience: 0/20
# Epoch [314/500]  Train Loss: 0.9209 | Val Loss: 1.0204 | Patience: 0/20
# Epoch [315/500]  Train Loss: 0.9203 | Val Loss: 1.0205 | Patience: 1/20
# Epoch [316/500]  Train Loss: 0.9201 | Val Loss: 1.0170 | Patience: 0/20
# Epoch [317/500]  Train Loss: 0.9194 | Val Loss: 1.0197 | Patience: 1/20
# Epoch [318/500]  Train Loss: 0.9180 | Val Loss: 1.0177 | Patience: 2/20
# Epoch [319/500]  Train Loss: 0.9170 | Val Loss: 1.0190 | Patience: 3/20
# Epoch [320/500]  Train Loss: 0.9158 | Val Loss: 1.0157 | Patience: 0/20
# Epoch [321/500]  Train Loss: 0.9158 | Val Loss: 1.0142 | Patience: 0/20
# Epoch [322/500]  Train Loss: 0.9147 | Val Loss: 1.0160 | Patience: 1/20
# Epoch [323/500]  Train Loss: 0.9142 | Val Loss: 1.0144 | Patience: 2/20
# Epoch [324/500]  Train Loss: 0.9124 | Val Loss: 1.0148 | Patience: 3/20
# Epoch [325/500]  Train Loss: 0.9119 | Val Loss: 1.0133 | Patience: 0/20
# Epoch [326/500]  Train Loss: 0.9107 | Val Loss: 1.0138 | Patience: 1/20
# Epoch [327/500]  Train Loss: 0.9120 | Val Loss: 1.0125 | Patience: 0/20
# Epoch [328/500]  Train Loss: 0.9086 | Val Loss: 1.0123 | Patience: 0/20
# Epoch [329/500]  Train Loss: 0.9084 | Val Loss: 1.0114 | Patience: 0/20
# Epoch [330/500]  Train Loss: 0.9074 | Val Loss: 1.0133 | Patience: 1/20
# Epoch [331/500]  Train Loss: 0.9063 | Val Loss: 1.0122 | Patience: 2/20
# Epoch [332/500]  Train Loss: 0.9051 | Val Loss: 1.0112 | Patience: 0/20
# Epoch [333/500]  Train Loss: 0.9038 | Val Loss: 1.0074 | Patience: 0/20
# Epoch [334/500]  Train Loss: 0.9033 | Val Loss: 1.0093 | Patience: 1/20
# Epoch [335/500]  Train Loss: 0.9013 | Val Loss: 1.0069 | Patience: 0/20
# Epoch [336/500]  Train Loss: 0.9012 | Val Loss: 1.0075 | Patience: 1/20
# Epoch [337/500]  Train Loss: 0.8995 | Val Loss: 1.0081 | Patience: 2/20
# Epoch [338/500]  Train Loss: 0.9007 | Val Loss: 1.0049 | Patience: 0/20
# Epoch [339/500]  Train Loss: 0.8978 | Val Loss: 1.0061 | Patience: 1/20
# Epoch [340/500]  Train Loss: 0.8972 | Val Loss: 1.0061 | Patience: 2/20
# Epoch [341/500]  Train Loss: 0.8958 | Val Loss: 1.0044 | Patience: 0/20
# Epoch [342/500]  Train Loss: 0.8969 | Val Loss: 1.0046 | Patience: 1/20
# Epoch [343/500]  Train Loss: 0.8958 | Val Loss: 1.0025 | Patience: 0/20
# Epoch [344/500]  Train Loss: 0.8933 | Val Loss: 1.0030 | Patience: 1/20
# Epoch [345/500]  Train Loss: 0.8934 | Val Loss: 1.0017 | Patience: 0/20
# Epoch [346/500]  Train Loss: 0.8917 | Val Loss: 1.0026 | Patience: 1/20
# Epoch [347/500]  Train Loss: 0.8922 | Val Loss: 1.0016 | Patience: 0/20
# Epoch [348/500]  Train Loss: 0.8902 | Val Loss: 1.0002 | Patience: 0/20
# Epoch [349/500]  Train Loss: 0.8886 | Val Loss: 1.0011 | Patience: 1/20
# Epoch [350/500]  Train Loss: 0.8872 | Val Loss: 1.0018 | Patience: 2/20
# Epoch [351/500]  Train Loss: 0.8880 | Val Loss: 1.0011 | Patience: 3/20
# Epoch [352/500]  Train Loss: 0.8853 | Val Loss: 0.9996 | Patience: 0/20
# Epoch [353/500]  Train Loss: 0.8853 | Val Loss: 0.9995 | Patience: 0/20
# Epoch [354/500]  Train Loss: 0.8853 | Val Loss: 0.9977 | Patience: 0/20
# Epoch [355/500]  Train Loss: 0.8844 | Val Loss: 0.9974 | Patience: 0/20
# Epoch [356/500]  Train Loss: 0.8836 | Val Loss: 0.9959 | Patience: 0/20
# Epoch [357/500]  Train Loss: 0.8818 | Val Loss: 0.9983 | Patience: 1/20
# Epoch [358/500]  Train Loss: 0.8821 | Val Loss: 0.9958 | Patience: 0/20
# Epoch [359/500]  Train Loss: 0.8789 | Val Loss: 0.9973 | Patience: 1/20
# Epoch [360/500]  Train Loss: 0.8783 | Val Loss: 0.9928 | Patience: 0/20
# Epoch [361/500]  Train Loss: 0.8781 | Val Loss: 0.9942 | Patience: 1/20
# Epoch [362/500]  Train Loss: 0.8766 | Val Loss: 0.9936 | Patience: 2/20
# Epoch [363/500]  Train Loss: 0.8762 | Val Loss: 0.9951 | Patience: 3/20
# Epoch [364/500]  Train Loss: 0.8758 | Val Loss: 0.9940 | Patience: 4/20
# Epoch [365/500]  Train Loss: 0.8743 | Val Loss: 0.9947 | Patience: 5/20
# Epoch [366/500]  Train Loss: 0.8740 | Val Loss: 0.9937 | Patience: 6/20
# Epoch [367/500]  Train Loss: 0.8731 | Val Loss: 0.9923 | Patience: 0/20
# Epoch [368/500]  Train Loss: 0.8708 | Val Loss: 0.9918 | Patience: 0/20
# Epoch [369/500]  Train Loss: 0.8703 | Val Loss: 0.9942 | Patience: 1/20
# Epoch [370/500]  Train Loss: 0.8693 | Val Loss: 0.9935 | Patience: 2/20
# Epoch [371/500]  Train Loss: 0.8676 | Val Loss: 0.9902 | Patience: 0/20
# Epoch [372/500]  Train Loss: 0.8668 | Val Loss: 0.9920 | Patience: 1/20
# Epoch [373/500]  Train Loss: 0.8674 | Val Loss: 0.9909 | Patience: 2/20
# Epoch [374/500]  Train Loss: 0.8660 | Val Loss: 0.9865 | Patience: 0/20
# Epoch [375/500]  Train Loss: 0.8646 | Val Loss: 0.9880 | Patience: 1/20
# Epoch [376/500]  Train Loss: 0.8637 | Val Loss: 0.9888 | Patience: 2/20
# Epoch [377/500]  Train Loss: 0.8646 | Val Loss: 0.9874 | Patience: 3/20
# Epoch [378/500]  Train Loss: 0.8629 | Val Loss: 0.9908 | Patience: 4/20
# Epoch [379/500]  Train Loss: 0.8604 | Val Loss: 0.9935 | Patience: 5/20
# Epoch [380/500]  Train Loss: 0.8618 | Val Loss: 0.9850 | Patience: 0/20
# Epoch [381/500]  Train Loss: 0.8584 | Val Loss: 0.9890 | Patience: 1/20
# Epoch [382/500]  Train Loss: 0.8577 | Val Loss: 0.9920 | Patience: 2/20
# Epoch [383/500]  Train Loss: 0.8593 | Val Loss: 0.9904 | Patience: 3/20
# Epoch [384/500]  Train Loss: 0.8576 | Val Loss: 0.9868 | Patience: 4/20
# Epoch [385/500]  Train Loss: 0.8556 | Val Loss: 0.9850 | Patience: 5/20
# Epoch [386/500]  Train Loss: 0.8543 | Val Loss: 0.9903 | Patience: 6/20
# Epoch [387/500]  Train Loss: 0.8540 | Val Loss: 0.9874 | Patience: 7/20
# Epoch [388/500]  Train Loss: 0.8523 | Val Loss: 0.9845 | Patience: 0/20
# Epoch [389/500]  Train Loss: 0.8520 | Val Loss: 0.9833 | Patience: 0/20
# Epoch [390/500]  Train Loss: 0.8517 | Val Loss: 0.9828 | Patience: 0/20
# Epoch [391/500]  Train Loss: 0.8495 | Val Loss: 0.9836 | Patience: 1/20
# Epoch [392/500]  Train Loss: 0.8495 | Val Loss: 0.9812 | Patience: 0/20
# Epoch [393/500]  Train Loss: 0.8480 | Val Loss: 0.9804 | Patience: 0/20
# Epoch [394/500]  Train Loss: 0.8479 | Val Loss: 0.9813 | Patience: 1/20
# Epoch [395/500]  Train Loss: 0.8451 | Val Loss: 0.9795 | Patience: 0/20
# Epoch [396/500]  Train Loss: 0.8456 | Val Loss: 0.9804 | Patience: 1/20
# Epoch [397/500]  Train Loss: 0.8439 | Val Loss: 0.9827 | Patience: 2/20
# Epoch [398/500]  Train Loss: 0.8430 | Val Loss: 0.9832 | Patience: 3/20
# Epoch [399/500]  Train Loss: 0.8419 | Val Loss: 0.9795 | Patience: 4/20
# Epoch [400/500]  Train Loss: 0.8413 | Val Loss: 0.9844 | Patience: 5/20
# Epoch [401/500]  Train Loss: 0.8409 | Val Loss: 0.9822 | Patience: 6/20
# Epoch [402/500]  Train Loss: 0.8392 | Val Loss: 0.9781 | Patience: 0/20
# Epoch [403/500]  Train Loss: 0.8384 | Val Loss: 0.9818 | Patience: 1/20
# Epoch [404/500]  Train Loss: 0.8374 | Val Loss: 0.9814 | Patience: 2/20
# Epoch [405/500]  Train Loss: 0.8366 | Val Loss: 0.9818 | Patience: 3/20
# Epoch [406/500]  Train Loss: 0.8356 | Val Loss: 0.9803 | Patience: 4/20
# Epoch [407/500]  Train Loss: 0.8360 | Val Loss: 0.9805 | Patience: 5/20
# Epoch [408/500]  Train Loss: 0.8350 | Val Loss: 0.9782 | Patience: 6/20
# Epoch [409/500]  Train Loss: 0.8329 | Val Loss: 0.9794 | Patience: 7/20
# Epoch [410/500]  Train Loss: 0.8326 | Val Loss: 0.9771 | Patience: 0/20
# Epoch [411/500]  Train Loss: 0.8318 | Val Loss: 0.9791 | Patience: 1/20
# Epoch [412/500]  Train Loss: 0.8306 | Val Loss: 0.9766 | Patience: 0/20
# Epoch [413/500]  Train Loss: 0.8294 | Val Loss: 0.9761 | Patience: 0/20
# Epoch [414/500]  Train Loss: 0.8301 | Val Loss: 0.9846 | Patience: 1/20
# Epoch [415/500]  Train Loss: 0.8275 | Val Loss: 0.9794 | Patience: 2/20
# Epoch [416/500]  Train Loss: 0.8265 | Val Loss: 0.9839 | Patience: 3/20
# Epoch [417/500]  Train Loss: 0.8293 | Val Loss: 0.9808 | Patience: 4/20
# Epoch [418/500]  Train Loss: 0.8258 | Val Loss: 0.9826 | Patience: 5/20
# Epoch [419/500]  Train Loss: 0.8244 | Val Loss: 0.9776 | Patience: 6/20
# Epoch [420/500]  Train Loss: 0.8235 | Val Loss: 0.9790 | Patience: 7/20
# Epoch [421/500]  Train Loss: 0.8214 | Val Loss: 0.9793 | Patience: 8/20
# Epoch [422/500]  Train Loss: 0.8221 | Val Loss: 0.9839 | Patience: 9/20
# Epoch [423/500]  Train Loss: 0.8201 | Val Loss: 0.9829 | Patience: 10/20
# Epoch [424/500]  Train Loss: 0.8217 | Val Loss: 0.9786 | Patience: 11/20
# Epoch [425/500]  Train Loss: 0.8177 | Val Loss: 0.9778 | Patience: 12/20
# Epoch [426/500]  Train Loss: 0.8186 | Val Loss: 0.9734 | Patience: 0/20
# Epoch [427/500]  Train Loss: 0.8157 | Val Loss: 0.9829 | Patience: 1/20
# Epoch [428/500]  Train Loss: 0.8167 | Val Loss: 0.9781 | Patience: 2/20
# Epoch [429/500]  Train Loss: 0.8146 | Val Loss: 0.9810 | Patience: 3/20
# Epoch [430/500]  Train Loss: 0.8133 | Val Loss: 0.9728 | Patience: 0/20
# Epoch [431/500]  Train Loss: 0.8125 | Val Loss: 0.9787 | Patience: 1/20
# Epoch [432/500]  Train Loss: 0.8112 | Val Loss: 0.9757 | Patience: 2/20
# Epoch [433/500]  Train Loss: 0.8128 | Val Loss: 0.9727 | Patience: 0/20
# Epoch [434/500]  Train Loss: 0.8101 | Val Loss: 0.9766 | Patience: 1/20
# Epoch [435/500]  Train Loss: 0.8093 | Val Loss: 0.9828 | Patience: 2/20
# Epoch [436/500]  Train Loss: 0.8089 | Val Loss: 0.9768 | Patience: 3/20
# Epoch [437/500]  Train Loss: 0.8076 | Val Loss: 0.9767 | Patience: 4/20
# Epoch [438/500]  Train Loss: 0.8062 | Val Loss: 0.9829 | Patience: 5/20
# Epoch [439/500]  Train Loss: 0.8057 | Val Loss: 0.9829 | Patience: 6/20
# Epoch [440/500]  Train Loss: 0.8061 | Val Loss: 0.9747 | Patience: 7/20
# Epoch [441/500]  Train Loss: 0.8043 | Val Loss: 0.9755 | Patience: 8/20
# Epoch [442/500]  Train Loss: 0.8034 | Val Loss: 0.9813 | Patience: 9/20
# Epoch [443/500]  Train Loss: 0.8023 | Val Loss: 0.9750 | Patience: 10/20
# Epoch [444/500]  Train Loss: 0.8029 | Val Loss: 0.9771 | Patience: 11/20
# Epoch [445/500]  Train Loss: 0.8032 | Val Loss: 0.9827 | Patience: 12/20
# Epoch [446/500]  Train Loss: 0.8008 | Val Loss: 0.9739 | Patience: 13/20
# Epoch [447/500]  Train Loss: 0.7987 | Val Loss: 0.9763 | Patience: 14/20
# Epoch [448/500]  Train Loss: 0.7981 | Val Loss: 0.9898 | Patience: 15/20
# Epoch [449/500]  Train Loss: 0.7973 | Val Loss: 0.9708 | Patience: 0/20
# Epoch [450/500]  Train Loss: 0.7973 | Val Loss: 0.9685 | Patience: 0/20
# Epoch [451/500]  Train Loss: 0.7960 | Val Loss: 0.9735 | Patience: 1/20
# Epoch [452/500]  Train Loss: 0.7940 | Val Loss: 0.9769 | Patience: 2/20
# Epoch [453/500]  Train Loss: 0.7940 | Val Loss: 0.9847 | Patience: 3/20
# Epoch [454/500]  Train Loss: 0.7922 | Val Loss: 0.9754 | Patience: 4/20
# Epoch [455/500]  Train Loss: 0.7913 | Val Loss: 0.9853 | Patience: 5/20
# Epoch [456/500]  Train Loss: 0.7909 | Val Loss: 0.9731 | Patience: 6/20
# Epoch [457/500]  Train Loss: 0.7893 | Val Loss: 0.9845 | Patience: 7/20
# Epoch [458/500]  Train Loss: 0.7880 | Val Loss: 0.9896 | Patience: 8/20
# Epoch [459/500]  Train Loss: 0.7911 | Val Loss: 0.9872 | Patience: 9/20
# Epoch [460/500]  Train Loss: 0.7883 | Val Loss: 0.9815 | Patience: 10/20
# Epoch [461/500]  Train Loss: 0.7874 | Val Loss: 0.9809 | Patience: 11/20
# Epoch [462/500]  Train Loss: 0.7859 | Val Loss: 0.9758 | Patience: 12/20
# Epoch [463/500]  Train Loss: 0.7834 | Val Loss: 0.9822 | Patience: 13/20
# Epoch [464/500]  Train Loss: 0.7837 | Val Loss: 0.9829 | Patience: 14/20
# Epoch [465/500]  Train Loss: 0.7835 | Val Loss: 0.9715 | Patience: 15/20
# Epoch [466/500]  Train Loss: 0.7835 | Val Loss: 0.9811 | Patience: 16/20
# Epoch [467/500]  Train Loss: 0.7829 | Val Loss: 0.9847 | Patience: 17/20
# Epoch [468/500]  Train Loss: 0.7805 | Val Loss: 0.9810 | Patience: 18/20
# Epoch [469/500]  Train Loss: 0.7807 | Val Loss: 0.9880 | Patience: 19/20
# Epoch [470/500]  Train Loss: 0.7785 | Val Loss: 0.9881 | Patience: 20/20
# Early stopping triggered at epoch 470.
# Best model saved as trained_model.pt

# %% [markdown]
# ### **Model Evaluation**

# %%
# Over a vast grid of thresholds, select the one maximizing balanced accuracy in validation set
threshold_grid = np.linspace(0.01, 0.99, 99)
_, y_val_true, y_val_probs, _ = evaluate(val_loader, model, criterion, threshold=0.5)
val_balanced_accuracy_scores = []

for threshold in threshold_grid:
    val_preds = (y_val_probs >= threshold).astype(int)
    val_balanced_accuracy_scores.append(balanced_accuracy_score(y_val_true, val_preds))

best_threshold = threshold_grid[int(np.argmax(val_balanced_accuracy_scores))]
best_val_balanced_accuracy = float(np.max(val_balanced_accuracy_scores))

test_loss, y_test_true, y_test_probs, y_test_pred = evaluate(
    test_loader, model, criterion, threshold=best_threshold
)

# Compute the evaluation metrics
test_accuracy = accuracy_score(y_test_true, y_test_pred)
test_balanced_accuracy = balanced_accuracy_score(y_test_true, y_test_pred)
test_roc_auc = roc_auc_score(y_test_true, y_test_probs)
cm = confusion_matrix(y_test_true, y_test_pred)
fpr, tpr, _ = roc_curve(y_test_true, y_test_probs)
roc_auc = auc(fpr, tpr)

print("\n========== Final Evaluation ==========%s" % "")
print(f"Best threshold (validated on validation set): {best_threshold:.2f}")
print(f"Validation balanced accuracy at best threshold: {best_val_balanced_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Balanced Accuracy: {test_balanced_accuracy:.4f}")
print(f"Test ROC AUC: {test_roc_auc:.4f}")

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Injury', 'Injury'])
fig, ax = plt.subplots(figsize=(6, 5))
disp.plot(ax=ax, cmap='Blues', values_format='d', colorbar=False)
plt.title('Confusion Matrix - Test Set')
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.4f})', linewidth=2)
plt.plot([0, 1], [0, 1], linestyle='--', linewidth=1, label='Random classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Test Set')
plt.legend(loc='lower right')
plt.grid(alpha=0.2)
plt.tight_layout()
plt.show()
# Out:
# ========== Final Evaluation ==========
# Best threshold (validated on validation set): 0.42
# Validation balanced accuracy at best threshold: 0.7560
# Test Loss: 1.4398
# Test Accuracy: 0.7112
# Test Balanced Accuracy: 0.6922
# Test ROC AUC: 0.7566
