# %%
# Dependencies
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Data loading
day_path = '../Dataset/day_approach_maskedID_timeseries.csv'
week_path = '../Dataset/week_approach_maskedID_timeseries.csv'

# Day and week dataframes
day_df = pd.read_csv(day_path)
week_df = pd.read_csv(week_path)

# Dataframe for our model
df = day_df.sort_values(by=['Date', 'Athlete ID'])
